# %% [markdown]
# # USING THE TRACKING METHOD

# %%
import cv2
import numpy as np
import os

# %%
# --- Configuration ---
DET_PROTOTXT = r"pretrained_models/deploy.prototxt.txt"
DET_MODEL = r"pretrained_models/res10_300x300_ssd_iter_140000.caffemodel"
REC_MODEL = r"pretrained_models/face_recognition_sface_2021dec.onnx"

#TARGET_IMAGE_FOLDER = "data/train"
TARGET_IMAGE_FOLDERS = ["data/train", "data/train_aug"]

CONFIDENCE_THRESHOLD = 0.5 # Minimum confidence for face detection
RECOGNITION_THRESHOLD = 0.9 # Cosine similarity threshold for matching (adjust based on testing)
TRACKING_ENABLED = True
TRACKER_TYPE = 'csrt' # Options: 'boosting', 'mil', 'kcf', 'tld', 'medianflow', 'mosse', 'csrt'
RE_DETECTION_INTERVAL = 30 # Re-run full detection every N frames

# %%
# --- Load Models ---
print("[INFO] Loading face detector model...")
detector_net = cv2.dnn.readNetFromCaffe(DET_PROTOTXT, DET_MODEL)

print("[INFO] Loading face recognition model...")
recognizer_net = cv2.dnn.readNetFromONNX(REC_MODEL)
print("LOADED!!!")
# Out:
# [INFO] Loading face detector model...
# [INFO] Loading face recognition model...
# LOADED!!!

# %%
target_embeddings = []
print(f"[INFO] Processing target images from folders: {TARGET_IMAGE_FOLDERS}...")

for folder in TARGET_IMAGE_FOLDERS:
    for image_name in os.listdir(folder):
        image_path = os.path.join(folder, image_name)
        image = cv2.imread(image_path)
        if image is None:
            print(f"Warning: Could not read image {image_path}")
            continue

        (h, w) = image.shape[:2]

        # 1. Detect face(s) in the target image
        blob = cv2.dnn.blobFromImage(cv2.resize(image, (300, 300)), 1.0, (300, 300), (104.0, 177.0, 123.0))
        detector_net.setInput(blob)
        detections = detector_net.forward()

        # Assume the largest face is the target if multiple are found
        best_face_confidence = -1
        best_face_box = None

        for i in range(0, detections.shape[2]):
            confidence = detections[0, 0, i, 2]
            if confidence > CONFIDENCE_THRESHOLD:
                # Get bounding box, ensuring it's within image bounds
                box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
                (startX, startY, endX, endY) = box.astype("int")
                startX = max(0, startX)
                startY = max(0, startY)
                endX = min(w - 1, endX)
                endY = min(h - 1, endY)

                # Basic check for valid box size
                if endX > startX and endY > startY:
                    if confidence > best_face_confidence:
                        best_face_confidence = confidence
                        best_face_box = (startX, startY, endX, endY)

        # 2. Extract embedding if a face was found
        if best_face_box is not None:
            (startX, startY, endX, endY) = best_face_box
            face_roi = image[startY:endY, startX:endX]

            if face_roi.size == 0:
                print(f"Warning: Empty face ROI extracted from {image_path}")
                continue

            # Preprocess face for recognition model (specific to SFace)
            face_blob = cv2.dnn.blobFromImage(face_roi, 1.0 / 127.5, (112, 112), (127.5, 127.5, 127.5), swapRB=True)
            recognizer_net.setInput(face_blob)
            embedding = recognizer_net.forward()
            target_embeddings.append(embedding.flatten()) # Store the flattened embedding vector
            print(f"    -> Added embedding from {image_name}")
        else:
            print(f"Warning: No face detected in {image_path} above threshold {CONFIDENCE_THRESHOLD}")

if not target_embeddings:
    print("[ERROR] No target embeddings generated. Check target images and detection settings.")
    exit()

print(f"[INFO] Generated {len(target_embeddings)} target embeddings from {len(os.listdir('data/train')) + len(os.listdir('data/train_aug')) if os.path.exists('data/train_aug') else len(os.listdir('data/train'))} images.")
# Out:
# [INFO] Processing target images from folders: ['data/train', 'data/train_aug']...
#     -> Added embedding from 1.jpg
#     -> Added embedding from 10.jpg
#     -> Added embedding from 100.jpeg
#     -> Added embedding from 101.jpeg
#     -> Added embedding from 102.jpeg
#     -> Added embedding from 103.jpeg
#     -> Added embedding from 104.jpeg
#     -> Added embedding from 105.jpeg
#     -> Added embedding from 106.jpeg
#     -> Added embedding from 107.jpeg
#     -> Added embedding from 108.jpeg
#     -> Added embedding from 109.jpeg
#     -> Added embedding from 11.jpg
#     -> Added embedding from 110.jpg
#     -> Added embedding from 111.jpg
#     -> Added embedding from 112.jpeg
#     -> Added embedding from 113.jpeg
#     -> Added embedding from 114.jpg
#     -> Added embedding from 115.jpeg
#     -> Added embedding from 116.jpg
#     -> Added embedding from 117.jpg
#     -> Added embedding from 118.jpg
#     -> Added embedding from 119.jpg
#     -> Added embedding from 12.jpg
#     -> Added embedding from 120.jpg
#     -> Added embedding from 121.jpg
#     -> Added embedding from 122.jpg
#     -> Added embedding from 123.jpg
#     -> Added embedding from 124.jpeg
#     -> Added embedding from 125.jpg
#     -> Added embedding from 126.jpeg
#     -> Added embedding from 13.jpg
#     -> Added embedding from 14.jpg
#     -> Added embedding from 15.jpg
#     -> Added embedding from 16.jpg
#     -> Added embedding from 17.jpg
#     -> Added embedding from 18.jpg
#     -> Added embedding from 19.jpg
#     -> Added embedding from 2.jpg
#     -> Added embedding from 20.jpg
#     -> Added embedding from 21.jpg
#     -> Added embedding from 22.jpeg
#     -> Added embedding from 23.jpg
#     -> Added embedding from 24.jpg
#     -> Added embedding from 25.jpg
#     -> Added embedding from 26.jpg
#     -> Added embedding from 27.jpg
#     -> Added embedding from 28.jpg
#     -> Added embedding from 29.jpg
#     -> Added embedding from 3.jpg
#     -> Added embedding from 30.jpg
#     -> Added embedding from 31.jpg
#     -> Added embedding from 32.jpg
#     -> Added embedding from 33.jpg
#     -> Added embedding from 34.jpg
#     -> Added embedding from 35.jpg
#     -> Added embedding from 36.jpg
#     -> Added embedding from 37.jpg
#     -> Added embedding from 38.jpg
#     -> Added embedding from 39.jpg
#     -> Added embedding from 4.jpg
#     -> Added embedding from 40.jpg
#     -> Added embedding from 41.jpg
#     -> Added embedding from 42.jpg
#     -> Added embedding from 43.jpg
#     -> Added embedding from 44.jpg
#     -> Added embedding from 45.jpg
#     -> Added embedding from 46.jpg
#     -> Added embedding from 47.jpg
#     -> Added embedding from 48.jpg
#     -> Added embedding from 49.jpg
#     -> Added embedding from 5.jpg
#     -> Added embedding from 50.jpg
#     -> Added embedding from 51.jpg
#     -> Added embedding from 52.jpg
#     -> Added embedding from 53.jpg
#     -> Added embedding from 54.jpg
#     -> Added embedding from 55.jpg
#     -> Added embedding from 56.jpg
#     -> Added embedding from 57.jpg
#     -> Added embedding from 58.jpg
#     -> Added embedding from 59.jpeg
#     -> Added embedding from 6.jpg
#     -> Added embedding from 60.jpg
#     -> Added embedding from 61.jpg
#     -> Added embedding from 62.jpg
#     -> Added embedding from 63.jpg
#     -> Added embedding from 64.jpg
#     -> Added embedding from 65.jpg
#     -> Added embedding from 66.jpg
#     -> Added embedding from 67.jpg
#     -> Added embedding from 68.jpg
#     -> Added embedding from 69.jpg
#     -> Added embedding from 7.jpg
#     -> Added embedding from 70.jpg
#     -> Added embedding from 71.jpg
#     -> Added embedding from 72.jpg
#     -> Added embedding from 73.jpg
#     -> Added embedding from 74.jpg
#     -> Added embedding from 75.jpeg
#     -> Added embedding from 76.jpeg
#     -> Added embedding from 77.jpg
#     -> Added embedding from 78.jpg
#     -> Added embedding from 79.jpg
#     -> Added embedding from 8.jpg
#     -> Added embedding from 80.jpg
#     -> Added embedding from 81.jpeg
#     -> Added embedding from 82.jpeg
#     -> Added embedding from 83.jpeg
#     -> Added embedding from 84.jpeg
#     -> Added embedding from 85.jpeg
#     -> Added embedding from 86.jpeg
#     -> Added embedding from 87.jpeg
#     -> Added embedding from 88.jpeg
#     -> Added embedding from 89.jpeg
#     -> Added embedding from 9.jpg
#     -> Added embedding from 90.jpeg
#     -> Added embedding from 91.jpeg
#     -> Added embedding from 92.jpeg
#     -> Added embedding from 93.jpeg
#     -> Added embedding from 94.jpeg
#     -> Added embedding from 95.jpeg
#     -> Added embedding from 96.jpeg
#     -> Added embedding from 97.jpeg
#     -> Added embedding from 98.jpeg
#     -> Added embedding from 99.jpeg
#     -> Added embedding from 100_aug_0.jpg
#     -> Added embedding from 100_aug_1.jpg
#     -> Added embedding from 100_aug_2.jpg
#     -> Added embedding from 101_aug_0.jpg
#     -> Added embedding from 101_aug_1.jpg
#     -> Added embedding from 101_aug_2.jpg
#     -> Added embedding from 102_aug_0.jpg
#     -> Added embedding from 102_aug_1.jpg
#     -> Added embedding from 102_aug_2.jpg
#     -> Added embedding from 103_aug_0.jpg
#     -> Added embedding from 103_aug_1.jpg
#     -> Added embedding from 103_aug_2.jpg
#     -> Added embedding from 104_aug_0.jpg
#     -> Added embedding from 104_aug_1.jpg
#     -> Added embedding from 104_aug_2.jpg
#     -> Added embedding from 105_aug_0.jpg
# Warning: No face detected in data/train_aug\105_aug_1.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\105_aug_2.jpg above threshold 0.5
#     -> Added embedding from 106_aug_0.jpg
#     -> Added embedding from 106_aug_1.jpg
#     -> Added embedding from 106_aug_2.jpg
#     -> Added embedding from 107_aug_0.jpg
# Warning: No face detected in data/train_aug\107_aug_1.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\107_aug_2.jpg above threshold 0.5
#     -> Added embedding from 108_aug_0.jpg
#     -> Added embedding from 108_aug_1.jpg
#     -> Added embedding from 108_aug_2.jpg
#     -> Added embedding from 109_aug_0.jpg
#     -> Added embedding from 109_aug_1.jpg
#     -> Added embedding from 109_aug_2.jpg
#     -> Added embedding from 10_aug_0.jpg
#     -> Added embedding from 10_aug_1.jpg
#     -> Added embedding from 10_aug_2.jpg
#     -> Added embedding from 110_aug_0.jpg
#     -> Added embedding from 110_aug_1.jpg
#     -> Added embedding from 110_aug_2.jpg
#     -> Added embedding from 111_aug_0.jpg
#     -> Added embedding from 111_aug_1.jpg
# Warning: No face detected in data/train_aug\111_aug_2.jpg above threshold 0.5
#     -> Added embedding from 112_aug_0.jpg
#     -> Added embedding from 112_aug_1.jpg
#     -> Added embedding from 112_aug_2.jpg
#     -> Added embedding from 113_aug_0.jpg
#     -> Added embedding from 113_aug_1.jpg
#     -> Added embedding from 113_aug_2.jpg
#     -> Added embedding from 114_aug_0.jpg
#     -> Added embedding from 114_aug_1.jpg
#     -> Added embedding from 114_aug_2.jpg
#     -> Added embedding from 115_aug_0.jpg
#     -> Added embedding from 115_aug_1.jpg
#     -> Added embedding from 115_aug_2.jpg
#     -> Added embedding from 116_aug_0.jpg
#     -> Added embedding from 116_aug_1.jpg
#     -> Added embedding from 116_aug_2.jpg
# Warning: No face detected in data/train_aug\117_aug_0.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\117_aug_1.jpg above threshold 0.5
#     -> Added embedding from 117_aug_2.jpg
# Warning: No face detected in data/train_aug\118_aug_0.jpg above threshold 0.5
#     -> Added embedding from 118_aug_1.jpg
#     -> Added embedding from 118_aug_2.jpg
#     -> Added embedding from 119_aug_0.jpg
#     -> Added embedding from 119_aug_1.jpg
#     -> Added embedding from 119_aug_2.jpg
#     -> Added embedding from 11_aug_0.jpg
#     -> Added embedding from 11_aug_1.jpg
#     -> Added embedding from 11_aug_2.jpg
#     -> Added embedding from 120_aug_0.jpg
#     -> Added embedding from 120_aug_1.jpg
#     -> Added embedding from 120_aug_2.jpg
#     -> Added embedding from 121_aug_0.jpg
# Warning: No face detected in data/train_aug\121_aug_1.jpg above threshold 0.5
#     -> Added embedding from 121_aug_2.jpg
#     -> Added embedding from 122_aug_0.jpg
#     -> Added embedding from 122_aug_1.jpg
# Warning: No face detected in data/train_aug\122_aug_2.jpg above threshold 0.5
#     -> Added embedding from 123_aug_0.jpg
# Warning: No face detected in data/train_aug\123_aug_1.jpg above threshold 0.5
#     -> Added embedding from 123_aug_2.jpg
#     -> Added embedding from 124_aug_0.jpg
#     -> Added embedding from 124_aug_1.jpg
#     -> Added embedding from 124_aug_2.jpg
#     -> Added embedding from 125_aug_0.jpg
#     -> Added embedding from 125_aug_1.jpg
#     -> Added embedding from 125_aug_2.jpg
# Warning: No face detected in data/train_aug\126_aug_0.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\126_aug_1.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\126_aug_2.jpg above threshold 0.5
#     -> Added embedding from 12_aug_0.jpg
# Warning: No face detected in data/train_aug\12_aug_1.jpg above threshold 0.5
#     -> Added embedding from 12_aug_2.jpg
# Warning: No face detected in data/train_aug\13_aug_0.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\13_aug_1.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\13_aug_2.jpg above threshold 0.5
#     -> Added embedding from 14_aug_0.jpg
#     -> Added embedding from 14_aug_1.jpg
#     -> Added embedding from 14_aug_2.jpg
#     -> Added embedding from 15_aug_0.jpg
#     -> Added embedding from 15_aug_1.jpg
#     -> Added embedding from 15_aug_2.jpg
#     -> Added embedding from 16_aug_0.jpg
#     -> Added embedding from 16_aug_1.jpg
#     -> Added embedding from 16_aug_2.jpg
#     -> Added embedding from 17_aug_0.jpg
#     -> Added embedding from 17_aug_1.jpg
#     -> Added embedding from 17_aug_2.jpg
# Warning: No face detected in data/train_aug\18_aug_0.jpg above threshold 0.5
#     -> Added embedding from 18_aug_1.jpg
#     -> Added embedding from 18_aug_2.jpg
#     -> Added embedding from 19_aug_0.jpg
#     -> Added embedding from 19_aug_1.jpg
# Warning: No face detected in data/train_aug\19_aug_2.jpg above threshold 0.5
#     -> Added embedding from 1_aug_0.jpg
#     -> Added embedding from 1_aug_1.jpg
#     -> Added embedding from 1_aug_2.jpg
# Warning: No face detected in data/train_aug\20_aug_0.jpg above threshold 0.5
#     -> Added embedding from 20_aug_1.jpg
#     -> Added embedding from 20_aug_2.jpg
# Warning: No face detected in data/train_aug\21_aug_0.jpg above threshold 0.5
#     -> Added embedding from 21_aug_1.jpg
#     -> Added embedding from 21_aug_2.jpg
#     -> Added embedding from 22_aug_0.jpg
# Warning: No face detected in data/train_aug\22_aug_1.jpg above threshold 0.5
#     -> Added embedding from 22_aug_2.jpg
# Warning: No face detected in data/train_aug\23_aug_0.jpg above threshold 0.5
#     -> Added embedding from 23_aug_1.jpg
# Warning: No face detected in data/train_aug\23_aug_2.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\24_aug_0.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\24_aug_1.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\24_aug_2.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\25_aug_0.jpg above threshold 0.5
#     -> Added embedding from 25_aug_1.jpg
#     -> Added embedding from 25_aug_2.jpg
#     -> Added embedding from 26_aug_0.jpg
#     -> Added embedding from 26_aug_1.jpg
#     -> Added embedding from 26_aug_2.jpg
# Warning: No face detected in data/train_aug\27_aug_0.jpg above threshold 0.5
#     -> Added embedding from 27_aug_1.jpg
#     -> Added embedding from 27_aug_2.jpg
#     -> Added embedding from 28_aug_0.jpg
#     -> Added embedding from 28_aug_1.jpg
#     -> Added embedding from 28_aug_2.jpg
#     -> Added embedding from 29_aug_0.jpg
# Warning: No face detected in data/train_aug\29_aug_1.jpg above threshold 0.5
#     -> Added embedding from 29_aug_2.jpg
#     -> Added embedding from 2_aug_0.jpg
# Warning: No face detected in data/train_aug\2_aug_1.jpg above threshold 0.5
#     -> Added embedding from 2_aug_2.jpg
#     -> Added embedding from 30_aug_0.jpg
# Warning: No face detected in data/train_aug\30_aug_1.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\30_aug_2.jpg above threshold 0.5
#     -> Added embedding from 31_aug_0.jpg
#     -> Added embedding from 31_aug_1.jpg
#     -> Added embedding from 31_aug_2.jpg
#     -> Added embedding from 32_aug_0.jpg
#     -> Added embedding from 32_aug_1.jpg
#     -> Added embedding from 32_aug_2.jpg
#     -> Added embedding from 33_aug_0.jpg
#     -> Added embedding from 33_aug_1.jpg
#     -> Added embedding from 33_aug_2.jpg
#     -> Added embedding from 34_aug_0.jpg
#     -> Added embedding from 34_aug_1.jpg
#     -> Added embedding from 34_aug_2.jpg
# Warning: No face detected in data/train_aug\35_aug_0.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\35_aug_1.jpg above threshold 0.5
#     -> Added embedding from 35_aug_2.jpg
#     -> Added embedding from 36_aug_0.jpg
#     -> Added embedding from 36_aug_1.jpg
#     -> Added embedding from 36_aug_2.jpg
#     -> Added embedding from 37_aug_0.jpg
#     -> Added embedding from 37_aug_1.jpg
#     -> Added embedding from 37_aug_2.jpg
# Warning: No face detected in data/train_aug\38_aug_0.jpg above threshold 0.5
#     -> Added embedding from 38_aug_1.jpg
#     -> Added embedding from 38_aug_2.jpg
# Warning: No face detected in data/train_aug\39_aug_0.jpg above threshold 0.5
#     -> Added embedding from 39_aug_1.jpg
#     -> Added embedding from 39_aug_2.jpg
#     -> Added embedding from 3_aug_0.jpg
#     -> Added embedding from 3_aug_1.jpg
#     -> Added embedding from 3_aug_2.jpg
#     -> Added embedding from 40_aug_0.jpg
#     -> Added embedding from 40_aug_1.jpg
#     -> Added embedding from 40_aug_2.jpg
#     -> Added embedding from 41_aug_0.jpg
#     -> Added embedding from 41_aug_1.jpg
#     -> Added embedding from 41_aug_2.jpg
#     -> Added embedding from 42_aug_0.jpg
#     -> Added embedding from 42_aug_1.jpg
#     -> Added embedding from 42_aug_2.jpg
#     -> Added embedding from 43_aug_0.jpg
#     -> Added embedding from 43_aug_1.jpg
#     -> Added embedding from 43_aug_2.jpg
#     -> Added embedding from 44_aug_0.jpg
#     -> Added embedding from 44_aug_1.jpg
#     -> Added embedding from 44_aug_2.jpg
#     -> Added embedding from 45_aug_0.jpg
#     -> Added embedding from 45_aug_1.jpg
#     -> Added embedding from 45_aug_2.jpg
#     -> Added embedding from 46_aug_0.jpg
#     -> Added embedding from 46_aug_1.jpg
#     -> Added embedding from 46_aug_2.jpg
#     -> Added embedding from 47_aug_0.jpg
# Warning: No face detected in data/train_aug\47_aug_1.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\47_aug_2.jpg above threshold 0.5
#     -> Added embedding from 48_aug_0.jpg
#     -> Added embedding from 48_aug_1.jpg
#     -> Added embedding from 48_aug_2.jpg
#     -> Added embedding from 49_aug_0.jpg
#     -> Added embedding from 49_aug_1.jpg
# Warning: No face detected in data/train_aug\49_aug_2.jpg above threshold 0.5
#     -> Added embedding from 4_aug_0.jpg
#     -> Added embedding from 4_aug_1.jpg
#     -> Added embedding from 4_aug_2.jpg
#     -> Added embedding from 50_aug_0.jpg
#     -> Added embedding from 50_aug_1.jpg
#     -> Added embedding from 50_aug_2.jpg
#     -> Added embedding from 51_aug_0.jpg
#     -> Added embedding from 51_aug_1.jpg
#     -> Added embedding from 51_aug_2.jpg
#     -> Added embedding from 52_aug_0.jpg
#     -> Added embedding from 52_aug_1.jpg
#     -> Added embedding from 52_aug_2.jpg
#     -> Added embedding from 53_aug_0.jpg
#     -> Added embedding from 53_aug_1.jpg
#     -> Added embedding from 53_aug_2.jpg
#     -> Added embedding from 54_aug_0.jpg
#     -> Added embedding from 54_aug_1.jpg
#     -> Added embedding from 54_aug_2.jpg
#     -> Added embedding from 55_aug_0.jpg
#     -> Added embedding from 55_aug_1.jpg
#     -> Added embedding from 55_aug_2.jpg
#     -> Added embedding from 56_aug_0.jpg
# Warning: No face detected in data/train_aug\56_aug_1.jpg above threshold 0.5
#     -> Added embedding from 56_aug_2.jpg
#     -> Added embedding from 57_aug_0.jpg
#     -> Added embedding from 57_aug_1.jpg
#     -> Added embedding from 57_aug_2.jpg
# Warning: No face detected in data/train_aug\58_aug_0.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\58_aug_1.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\58_aug_2.jpg above threshold 0.5
#     -> Added embedding from 59_aug_0.jpg
#     -> Added embedding from 59_aug_1.jpg
#     -> Added embedding from 59_aug_2.jpg
#     -> Added embedding from 5_aug_0.jpg
#     -> Added embedding from 5_aug_1.jpg
#     -> Added embedding from 5_aug_2.jpg
#     -> Added embedding from 60_aug_0.jpg
#     -> Added embedding from 60_aug_1.jpg
# Warning: No face detected in data/train_aug\60_aug_2.jpg above threshold 0.5
#     -> Added embedding from 61_aug_0.jpg
# Warning: No face detected in data/train_aug\61_aug_1.jpg above threshold 0.5
#     -> Added embedding from 61_aug_2.jpg
#     -> Added embedding from 62_aug_0.jpg
#     -> Added embedding from 62_aug_1.jpg
#     -> Added embedding from 62_aug_2.jpg
#     -> Added embedding from 63_aug_0.jpg
#     -> Added embedding from 63_aug_1.jpg
#     -> Added embedding from 63_aug_2.jpg
#     -> Added embedding from 64_aug_0.jpg
# Warning: No face detected in data/train_aug\64_aug_1.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\64_aug_2.jpg above threshold 0.5
#     -> Added embedding from 65_aug_0.jpg
#     -> Added embedding from 65_aug_1.jpg
#     -> Added embedding from 65_aug_2.jpg
#     -> Added embedding from 66_aug_0.jpg
#     -> Added embedding from 66_aug_1.jpg
#     -> Added embedding from 66_aug_2.jpg
#     -> Added embedding from 67_aug_0.jpg
# Warning: No face detected in data/train_aug\67_aug_1.jpg above threshold 0.5
#     -> Added embedding from 67_aug_2.jpg
#     -> Added embedding from 68_aug_0.jpg
#     -> Added embedding from 68_aug_1.jpg
#     -> Added embedding from 68_aug_2.jpg
#     -> Added embedding from 69_aug_0.jpg
# Warning: No face detected in data/train_aug\69_aug_1.jpg above threshold 0.5
#     -> Added embedding from 69_aug_2.jpg
#     -> Added embedding from 6_aug_0.jpg
#     -> Added embedding from 6_aug_1.jpg
#     -> Added embedding from 6_aug_2.jpg
#     -> Added embedding from 70_aug_0.jpg
#     -> Added embedding from 70_aug_1.jpg
#     -> Added embedding from 70_aug_2.jpg
#     -> Added embedding from 71_aug_0.jpg
#     -> Added embedding from 71_aug_1.jpg
#     -> Added embedding from 71_aug_2.jpg
# Warning: No face detected in data/train_aug\72_aug_0.jpg above threshold 0.5
#     -> Added embedding from 72_aug_1.jpg
#     -> Added embedding from 72_aug_2.jpg
#     -> Added embedding from 73_aug_0.jpg
#     -> Added embedding from 73_aug_1.jpg
# Warning: No face detected in data/train_aug\73_aug_2.jpg above threshold 0.5
#     -> Added embedding from 74_aug_0.jpg
#     -> Added embedding from 74_aug_1.jpg
#     -> Added embedding from 74_aug_2.jpg
#     -> Added embedding from 75_aug_0.jpg
#     -> Added embedding from 75_aug_1.jpg
# Warning: No face detected in data/train_aug\75_aug_2.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\76_aug_0.jpg above threshold 0.5
#     -> Added embedding from 76_aug_1.jpg
# Warning: No face detected in data/train_aug\76_aug_2.jpg above threshold 0.5
#     -> Added embedding from 77_aug_0.jpg
#     -> Added embedding from 77_aug_1.jpg
#     -> Added embedding from 77_aug_2.jpg
#     -> Added embedding from 78_aug_0.jpg
#     -> Added embedding from 78_aug_1.jpg
#     -> Added embedding from 78_aug_2.jpg
#     -> Added embedding from 79_aug_0.jpg
#     -> Added embedding from 79_aug_1.jpg
#     -> Added embedding from 79_aug_2.jpg
#     -> Added embedding from 7_aug_0.jpg
#     -> Added embedding from 7_aug_1.jpg
#     -> Added embedding from 7_aug_2.jpg
# Warning: No face detected in data/train_aug\80_aug_0.jpg above threshold 0.5
#     -> Added embedding from 80_aug_1.jpg
#     -> Added embedding from 80_aug_2.jpg
#     -> Added embedding from 81_aug_0.jpg
#     -> Added embedding from 81_aug_1.jpg
#     -> Added embedding from 81_aug_2.jpg
#     -> Added embedding from 82_aug_0.jpg
#     -> Added embedding from 82_aug_1.jpg
#     -> Added embedding from 82_aug_2.jpg
# Warning: No face detected in data/train_aug\83_aug_0.jpg above threshold 0.5
#     -> Added embedding from 83_aug_1.jpg
# Warning: No face detected in data/train_aug\83_aug_2.jpg above threshold 0.5
#     -> Added embedding from 84_aug_0.jpg
#     -> Added embedding from 84_aug_1.jpg
#     -> Added embedding from 84_aug_2.jpg
#     -> Added embedding from 85_aug_0.jpg
#     -> Added embedding from 85_aug_1.jpg
#     -> Added embedding from 85_aug_2.jpg
#     -> Added embedding from 86_aug_0.jpg
#     -> Added embedding from 86_aug_1.jpg
#     -> Added embedding from 86_aug_2.jpg
#     -> Added embedding from 87_aug_0.jpg
#     -> Added embedding from 87_aug_1.jpg
#     -> Added embedding from 87_aug_2.jpg
# Warning: No face detected in data/train_aug\88_aug_0.jpg above threshold 0.5
#     -> Added embedding from 88_aug_1.jpg
#     -> Added embedding from 88_aug_2.jpg
#     -> Added embedding from 89_aug_0.jpg
#     -> Added embedding from 89_aug_1.jpg
# Warning: No face detected in data/train_aug\89_aug_2.jpg above threshold 0.5
# Warning: No face detected in data/train_aug\8_aug_0.jpg above threshold 0.5
#     -> Added embedding from 8_aug_1.jpg
# Warning: No face detected in data/train_aug\8_aug_2.jpg above threshold 0.5
#     -> Added embedding from 90_aug_0.jpg
#     -> Added embedding from 90_aug_1.jpg
#     -> Added embedding from 90_aug_2.jpg
#     -> Added embedding from 91_aug_0.jpg
#     -> Added embedding from 91_aug_1.jpg
#     -> Added embedding from 91_aug_2.jpg
#     -> Added embedding from 92_aug_0.jpg
#     -> Added embedding from 92_aug_1.jpg
#     -> Added embedding from 92_aug_2.jpg
#     -> Added embedding from 93_aug_0.jpg
#     -> Added embedding from 93_aug_1.jpg
#     -> Added embedding from 93_aug_2.jpg
#     -> Added embedding from 94_aug_0.jpg
#     -> Added embedding from 94_aug_1.jpg
#     -> Added embedding from 94_aug_2.jpg
#     -> Added embedding from 95_aug_0.jpg
#     -> Added embedding from 95_aug_1.jpg
#     -> Added embedding from 95_aug_2.jpg
#     -> Added embedding from 96_aug_0.jpg
#     -> Added embedding from 96_aug_1.jpg
#     -> Added embedding from 96_aug_2.jpg
#     -> Added embedding from 97_aug_0.jpg
# Warning: No face detected in data/train_aug\97_aug_1.jpg above threshold 0.5
#     -> Added embedding from 97_aug_2.jpg
#     -> Added embedding from 98_aug_0.jpg
#     -> Added embedding from 98_aug_1.jpg
#     -> Added embedding from 98_aug_2.jpg
#     -> Added embedding from 99_aug_0.jpg
#     -> Added embedding from 99_aug_1.jpg
#     -> Added embedding from 99_aug_2.jpg
#     -> Added embedding from 9_aug_0.jpg
#     -> Added embedding from 9_aug_1.jpg
#     -> Added embedding from 9_aug_2.jpg
# [INFO] Generated 440 target embeddings from 504 images.

# %%
# --- Video Processing ---
VIDEO_SOURCE = "data/test/vid1.mp4" # Or 0 for webcam
OUTPUT_VIDEO_PATH = "data/test/vid1_processed_tracked_aug.mp4" # Optional: Save output
BLUR_KERNEL_SIZE = (99, 99) # Must be odd numbers; larger means more blur

print(f"[INFO] Starting video processing from {VIDEO_SOURCE}...")
cap = cv2.VideoCapture(VIDEO_SOURCE)

# Optional: Setup Video Writer
writer = None
if OUTPUT_VIDEO_PATH:
    try:
        # Get video properties for the writer
        frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fps = int(cap.get(cv2.CAP_PROP_FPS))
        # Define the codec and create VideoWriter object
        fourcc = cv2.VideoWriter_fourcc(*'mp4v') # Or 'XVID', 'MJPG', etc.
        writer = cv2.VideoWriter(OUTPUT_VIDEO_PATH, fourcc, fps, (frame_width, frame_height))
        print(f"[INFO] Output video will be saved to {OUTPUT_VIDEO_PATH}")
    except Exception as e:
        print(f"[WARNING] Could not initialize video writer: {e}")
        writer = None

# Cosine Similarity function
def cosine_similarity(vec1, vec2):
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    if norm_vec1 == 0 or norm_vec2 == 0:
        return 0.0 # Avoid division by zero
    return np.dot(vec1, vec2) / (norm_vec1 * norm_vec2)

# Initialize tracker
tracker = None
target_tracked = False
frame_count = 0
target_bbox = None

def create_tracker(tracker_type):
    if tracker_type == 'boosting':
        return cv2.legacy.TrackerBoosting_create()
    elif tracker_type == 'mil':
        return cv2.legacy.TrackerMIL_create()
    elif tracker_type == 'kcf':
        return cv2.legacy.TrackerKCF_create()
    elif tracker_type == 'tld':
        return cv2.legacy.TrackerTLD_create()
    elif tracker_type == 'medianflow':
        return cv2.legacy.TrackerMedianFlow_create()
    elif tracker_type == 'mosse':
        return cv2.legacy.TrackerMOSSE_create()
    elif tracker_type == "csrt":
        return cv2.legacy.TrackerCSRT_create()
    else:
        print("Invalid tracker type. Using CSRT by default.")
        return cv2.legacy.TrackerCSRT_create()

while True:
    ret, frame = cap.read()
    if not ret:
        print("[INFO] End of video stream.")
        break

    (h, w) = frame.shape[:2]

    if not TRACKING_ENABLED or not target_tracked or (frame_count % RE_DETECTION_INTERVAL == 0):
        # Perform face detection and recognition
        blob = cv2.dnn.blobFromImage(cv2.resize(frame, (300, 300)), 1.0, (300, 300), (104.0, 177.0, 123.0))
        detector_net.setInput(blob)
        detections = detector_net.forward()

        best_match_confidence = -1
        best_match_box = None
        matched_target = False

        for i in range(0, detections.shape[2]):
            confidence = detections[0, 0, i, 2]

            if confidence > CONFIDENCE_THRESHOLD:
                box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
                (startX, startY, endX, endY) = box.astype("int")
                startX = max(0, startX)
                startY = max(0, startY)
                endX = min(w - 1, endX)
                endY = min(h - 1, endY)

                if endX > startX and endY > startY:
                    face_roi = frame[startY:endY, startX:endX]
                    if face_roi.size == 0: continue

                    face_blob = cv2.dnn.blobFromImage(face_roi, 1.0 / 127.5, (112, 112), (127.5, 127.5, 127.5), swapRB=True)
                    recognizer_net.setInput(face_blob)
                    current_embedding = recognizer_net.forward().flatten()

                    for target_emb in target_embeddings:
                        similarity = cosine_similarity(current_embedding, target_emb)
                        if similarity > RECOGNITION_THRESHOLD:
                            matched_target = True
                            best_match_box = (startX, startY, endX - startX, endY - startY) # Tracker needs (x, y, w, h)
                            target_tracked = True
                            if TRACKING_ENABLED:
                                tracker = create_tracker(TRACKER_TYPE)
                                tracker.init(frame, best_match_box)
                            break # Target found, no need to check other embeddings
                    if matched_target:
                        break # Target found, no need to check other detections

        if not matched_target:
            target_tracked = False
            target_bbox = None

    elif TRACKING_ENABLED and target_tracked and tracker is not None:
        # Track the target
        success, bbox = tracker.update(frame)
        if success:
            (x, y, w_track, h_track) = [int(v) for v in bbox]
            target_bbox = (x, y, x + w_track, y + h_track)
        else:
            target_tracked = False
            target_bbox = None
            tracker = None # Reset tracker if tracking fails

    # Apply blurring if target is identified or tracked
    if target_tracked and target_bbox is not None:
        startX, startY, endX, endY = target_bbox
        face_roi = frame[startY:endY, startX:endX]
        if face_roi.size > 0:
            blurred_face = cv2.GaussianBlur(face_roi, (BLUR_KERNEL_SIZE[0] // 2 * 2 + 1, BLUR_KERNEL_SIZE[1] // 2 * 2 + 1), 0) # Ensure odd kernel size
            frame[startY:endY, startX:endX] = blurred_face
            cv2.rectangle(frame, (startX, startY), (endX, endY), (0, 0, 255), 2) # Red box for target

    # Display the output frame
    cv2.imshow("Frame", frame)

    # Write frame to output video (if writer is initialized)
    if writer is not None:
        writer.write(frame)

    # Exit condition
    key = cv2.waitKey(1) & 0xFF
    if key == ord("q"):
        break

    frame_count += 1

# --- Cleanup ---
print("[INFO] Cleaning up...")
cap.release()
if writer is not None:
    writer.release()
cv2.destroyAllWindows()
print("[INFO] Finished.")
# Out:
# [INFO] Starting video processing from data/test/vid1.mp4...
# [INFO] Output video will be saved to data/test/vid1_PROCESSED_TRACKED.mp4
# [INFO] End of video stream.
# [INFO] Cleaning up...
# [INFO] Finished.
